# %%
# step 1: read packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
visa_df=pd.read_csv(r"D:\data files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# prevailing_wage

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
-count
-min
-25p
-50p
-mean
-median
-75p
-max
# Out:
#   Cell In[131], line 3
#     -25p
#       ^
# SyntaxError: invalid decimal literal

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
        visa_df['prevailing_wage'].count(),
        visa_df['prevailing_wage'].min(),
        visa_df['prevailing_wage'].quantile(0.25),
        visa_df['prevailing_wage'].quantile(0.50),
        visa_df['prevailing_wage'].mean(),
        visa_df['prevailing_wage'].median(),
        visa_df['prevailing_wage'].quantile(0.75),
        visa_df['prevailing_wage'].max()
# Out:
# 319210.27

# %%
pwage=visa_df['prevailing_wage']

# %%
l=[pwage.count(),
   pwage.min(),
   round(np.percentile(pwage,25),2),
   pwage.max(),
   round(pwage.mean(),2),
   round(pwage.median(),2),
   round(np.percentile(pwage,50),2),
   round(np.percentile(pwage,75),2)]

ID=['count','min','25p','max','mean','median','50p','75p']
pd.DataFrame(l,columns=['prevailing_wage'],index=ID)
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# 25p          34015.4800
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# 50p          70308.2100
# 75p         107735.5100

# %%
count=pwage.count()
min=pwage.min()
p_25=round(np.percentile(pwage,25),2)
max=pwage.max()
mean=round(pwage.mean(),2),
median=round(pwage.median(),2),
p_50=round(np.percentile(pwage,50),2),
p_75=round(np.percentile(pwage,75),2)
##########################################################
l=[count,min,p_25,mean,median,p_50,p_75,max]
###########################################################
ID=['count','min','25p','mean','median','50p','75p','max']
pd.DataFrame(l,columns=['prevailing_wage'],
             index=ID)
# Out:
#        prevailing_wage
# count            25480
# min             2.1367
# 25p           34015.48
# mean       (74455.81,)
# median     (70308.21,)
# 50p        (70308.21,)
# 75p          107735.51
# max          319210.27

# %%
# If i want to create a Df with 3 columns I need 3 lists
df=pd.DataFrame()
df['']=[10,20]
df['2']=[20,30]
df
# Out:
#         2
# 0  10  20
# 1  20  30

# %%
final_list=[]
for i in num:
    min=visa_df[i].min()
    count=visa_df[i].count()
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    p_25=round(np.percentile(visa_df[i],25),2)
    p_50=round(np.percentile(visa_df[i],50),2)
    p_75=round(np.percentile(visa_df[i],75),2)
    max=visa_df[i].max()
    l=[count,min,p_25,mean,median,p_50,p_75,max]
    final_list.append(l)

df=pd.DataFrame()
for i in final_list:
    df[f'{i}']=i
df.columns=num
df.index=ID
df
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# min              -26.00      1800.00           2.1367
# 25p             1022.00      1976.00       34015.4800
# max             5667.04      1979.41       74455.8100
# mean            2109.00      1997.00       70308.2100
# median          2109.00      1997.00       70308.2100
# 50p             3504.00      2005.00      107735.5100
# 75p           602069.00      2016.00      319210.2700

# %%
# describe function

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
visa_df.describe().T
# Out:
#                    count          mean           std        min       25%  \
# no_of_employees  25480.0   5667.043210  22877.928848   -26.0000   1022.00
# yr_of_estab      25480.0   1979.409929     42.366929  1800.0000   1976.00
# prevailing_wage  25480.0  74455.814592  52815.942327     2.1367  34015.48
#
#                       50%          75%        max
# no_of_employees   2109.00    3504.0000  602069.00
# yr_of_estab       1997.00    2005.0000    2016.00
# prevailing_wage  70308.21  107735.5125  319210.27

# %%
- data type seperate
- columns seperated
- frequency table
- math information
# Out:
#   Cell In[143], line 1
#     - data type seperate
#            ^
# SyntaxError: invalid syntax

# %%
#percentile

# %%
wage_data=visa_df['prevailing_wage']
np.percentile(wage_data,25)
# Out:
# np.float64(34015.479999999996)

# %%
- 25 percentage of number of applicants have the wage lower than 34015
- 25%(25480) has salary less than 34015
- 6370 applicants has salary less than 34015
# Out:
#   Cell In[146], line 1
#     - 25 percentage of number of applicants have the wage lower than 34015
#          ^
# SyntaxError: invalid syntax

# %%
wage_data=visa_df['prevailing_wage']          
con=wage_data<np.percentile(wage_data,25)      # how many people have wage less than 34015
np.sum(con)
# Out:
# np.int64(6370)

# %%
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# empricial rule

# %%
- 68% of data available between u-1*sd to u+1*sd

- step-1: calculate mean of wage: mean=74455

- step-2: calculate sd of wage: sd: 52815

- step-3: lb=mean-1*sd : 21640

- step-4: ub=mean+1*sd  : 127270

- step-5: con1= wage_data>lb

- step-6: con2= wage_data<ub

- step-7: con= con1 & con2

- step-8: np.sum(con): 17170

- step-9: 68%(25480) : 96328

# %%
# step-1: calculate mean of wage: mean=74455
wage_data=visa_df['prevailing_wage']
mean=wage_data.mean()
#step-2: calculate sd of wage: sd: 52815
sd=wage_data.std()
#step-3: lb=mean-1*sd : 21640
lb=mean-1*sd
#step-4: ub=mean+1*sd  : 127270
ub=mean+1*sd
#step-5: con1= wage_data>lb
con1= wage_data>lb
#step-6: con2= wage_data<ub
con2= wage_data<ub
# step-7: con= con1 & con2
con= con1 & con2
# step-8: np.sum(con): 17170
np.sum(con)==68*(25480)/100
# Out:
# np.False_

# %%
wage_data=visa_df['prevailing_wage']
mean=wage_data.mean()
sd=wage_data.std()
lb=mean-1*sd
ub=mean+1*sd
con1= wage_data>lb
con2= wage_data<ub
con= con1 & con2
np.sum(con),68*(25480)/100
# Out:
# (np.int64(17171), 17326.4)

# %%
#conclusion is wage data does not follow normal distribution

# %%
wage_data=visa_df['prevailing_wage']
mean=wage_data.mean()
sd=wage_data.std()
lb=mean-2*sd
ub=mean+2*sd
con1= wage_data>lb
con2= wage_data<ub
con= con1 & con2
np.sum(con),95*(25480)/100
# Out:
# (np.int64(24582), 24206.0)

# %%
wage_data=visa_df['prevailing_wage']
mean=wage_data.mean()
sd=wage_data.std()
lb=mean-3*sd
ub=mean+3*sd
con1= wage_data>lb
con2= wage_data<ub
con= con1 & con2
np.sum(con),99.7*(25480)/100
# Out:
# (np.int64(25186), 25403.56)

# %%
# histogram

# %%
wage_data=visa_df['prevailing_wage']


plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
# box plot
                                                                    august 6
.. code-block:: none

          Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
                       |-----:-----|
       o      |--------|     :     |--------|    o  o
                       |-----:-----|
     flier             <----------->            fliers
                            IQR

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
# how many outlier

# %%
# step-1 : q1
# step-2 : q2
# step-3 : q3
# step-4 : iqr= q3-q1
# step-5 : lb=q1-1.5*iqr
# step-5 : ub=q3+1.5*iqr
# step-6 : con1
# step-7 : con2
# step-8 : con=con1 con2
# step-9 : numpy
import numpy as np

# Example data
data = np.array([10, 12, 13, 14, 15, 16, 18, 20, 25, 100])

# Step 1: Find Q1
q1 = np.percentile(data, 25)

# Step 2: Find Q3
q3 = np.percentile(data, 75)

# Step 3: Find IQR
iqr = q3 - q1

# Step 4: Find Lower Bound and Upper Bound
lb = q1 - 1.5 * iqr
ub = q3 + 1.5 * iqr

# Step 5: Conditions for outliers
con1 = data < lb
con2 = data > ub

# Step 6: Combine both conditions
con = con1 | con2

# Step 7: Find outliers
outliers = data[con]

# Step 8: Count outliers
count = np.sum(con)

# 25480=== 427 outliers 427 replace with median
# box plot 
#outliner will affect by mean not median

# %%
wage_data=visa_df['prevailing_wage']
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data,50)
q3 = np.percentile(wage_data,75)
iqr= q3-q1
lb = q1 - 1.5 * iqr
ub = q3 + 1.5 * iqr
con1 = wage_data < lb
con2 = wage_data > ub
con  = con1|con2
wage_data[con]
np.sum(con)
# Out:
# np.int64(427)

# %%
wage_data[con]
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
visa_df[con]  # entire data
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
wage_data[con]      # it is in series then we convert in to values below
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
wage_data[con].values
# Out:
# array([220081.73, 225569.73, 247393.01, 269321.68, 219529.62, 232227.33,
#        238691.32, 220448.17, 230750.48, 235339.91, 232680.65, 256261.78,
#        262189.  , 250510.67, 218554.78, 256205.38, 221944.22, 229950.7 ,
#        222628.84, 229819.69, 233641.72, 274019.43, 218982.83, 230984.28,
#        223128.23, 246705.  , 240266.34, 226090.72, 231949.27, 254604.08,
#        288318.91, 244457.48, 242146.48, 247545.23, 234139.17, 231834.72,
#        222730.57, 239773.63, 220553.95, 237539.32, 266440.49, 277281.01,
#        275627.59, 249291.12, 292106.59, 234012.11, 247009.24, 267726.09,
#        222098.09, 280661.13, 277984.52, 262852.71, 263877.21, 230916.64,
#        264760.64, 267868.56, 222221.67, 242406.32, 276894.08, 281832.93,
#        221033.57, 258292.84, 223492.85, 245418.67, 250289.08, 271344.69,
#        252825.11, 230843.7 , 253668.86, 245819.17, 239465.3 , 236316.36,
#        225268.13, 228941.33, 306021.96, 228074.25, 270799.93, 221982.69,
# ...

# %%
wage_outliers=wage_data[con].values

# %%
# fill the outliners with median

# %%
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
wage_data[con].values
# Out:
# array([220081.73, 225569.73, 247393.01, 269321.68, 219529.62, 232227.33,
#        238691.32, 220448.17, 230750.48, 235339.91, 232680.65, 256261.78,
#        262189.  , 250510.67, 218554.78, 256205.38, 221944.22, 229950.7 ,
#        222628.84, 229819.69, 233641.72, 274019.43, 218982.83, 230984.28,
#        223128.23, 246705.  , 240266.34, 226090.72, 231949.27, 254604.08,
#        288318.91, 244457.48, 242146.48, 247545.23, 234139.17, 231834.72,
#        222730.57, 239773.63, 220553.95, 237539.32, 266440.49, 277281.01,
#        275627.59, 249291.12, 292106.59, 234012.11, 247009.24, 267726.09,
#        222098.09, 280661.13, 277984.52, 262852.71, 263877.21, 230916.64,
#        264760.64, 267868.56, 222221.67, 242406.32, 276894.08, 281832.93,
#        221033.57, 258292.84, 223492.85, 245418.67, 250289.08, 271344.69,
#        252825.11, 230843.7 , 253668.86, 245819.17, 239465.3 , 236316.36,
#        225268.13, 228941.33, 306021.96, 228074.25, 270799.93, 221982.69,
# ...

# %%
wage_outliers=wage_data[con].values

# %%
wage_data
take empty list
apply for loop 
if i in wage_outliner
apply median
else
append i

# %%
l= []
for i in wage_data:                             # i is wage data values
    if i in wage_outliers:
        l.append(q2)                            # i in outliner and that outliner will get changed to q2 median
    else:                                 
        l.append(i)

visa_df['wage_q2']=l

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data=visa_df['prevailing_wage']
wage_data_q2=visa_df['wage_q2']
plt.figure(figsize=(10,4))
plt.subplot(1,2,1).boxplot(wage_data,vert=False)
plt.subplot(1,2,2).boxplot(wage_data_q2,vert=False)
plt.show()

# %%
np.where

# %%
# capping
- we can fill outliners which less than 25p with 25p value
- we can fill outlier which less than 75p with 75p value

# %%
wage_data=visa_df['prevailing_wage']
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data,50)
q3 = np.percentile(wage_data,75)
iqr= q3-q1
lb = q1 - 1.5 * iqr                                      #cap<25p == 25p == lb
ub = q3 + 1.5 * iqr                                      #cap>75p == 75p == ub
visa_df['wage_data_cap']=wage_data.clip(lb,ub)

# %%
lb
# Out:
# np.float64(-76564.56875000002)

# %%
ub
# Out:
# np.float64(218315.56125000003)

# %%
wage_data.clip(lb,ub)
# Out:
# 0           592.20290
# 1         83425.65000
# 2        122996.86000
# 3         83434.03000
# 4        149907.39000
#              ...
# 25475     77092.57000
# 25476    218315.56125
# 25477    146298.85000
# 25478     86154.77000
# 25479     70876.91000
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data=visa_df['prevailing_wage']
wage_data_q2=visa_df['wage_q2']
wage_data_cap=visa_df['wage_data_cap']
plt.figure(figsize=(14,4))
plt.subplot(1,3,1).boxplot(wage_data,vert=False)
plt.subplot(1,3,2).boxplot(wage_data_q2,vert=False)
plt.subplot(1,3,3).boxplot(wage_data_cap,vert=False)
plt.show()
