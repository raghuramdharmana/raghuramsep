# %%
# step 1: read packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
visa_df=pd.read_csv(r"D:\data files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
                                      Data read
                                          |
                                     Data cleaning
                                          |
                                     Data Analysis
                                          |
                                    Feature engineering
                                          |
                                    Feature selection
                                          |
                                     Model development
                                          |
                                     Model evalution
                                          |
                                      Model tuning
                                          |
                                      Model deployment

# %%
#                                                  Feature engineering


- so far we have performed feautre analysis
   - data frame quick checks
   - catergorical column analysis
   - bar chart,pie chart
   - numerical column analysis
   - histogram, boxplot,outliners
   - bi- multi variate analysis
   - correlation etc

- now we need to learn feature engineering
   - we will create a new columns for better ml models
   - we will perform the encoding,which is convert categorical to numerical data
   - we will do data transformations.
   - we will perform scaling : standardization and normalization.
   - we will perform the missing value analysis.

- simply feature engineering means our data will be modified

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# case status

# %%
# first check how many unqiue labels are there in case_status
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# create dictionary
d={'Certified':0,'Denied':1}

# %%
# map the above dictionary with original column
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
e={'High School':0, "Master's":1, "Bachelor's":2, 'Doctorate':3}

# %%
visa_df['education_of_employee']=visa_df['education_of_employee'].map(e)

# %%
visa_df['education_of_employee']
# Out:
# 0        0
# 1        1
# 2        2
# 3        2
# 4        1
#         ..
# 25475    2
# 25476    0
# 25477    1
# 25478    1
# 25479    2
# Name: education_of_employee, Length: 25480, dtype: int64

# %%
labels=sorted(visa_df['education_of_employee'].unique())
d={j:i for i,j in enumerate(labels)}                          # i for number and j for education.
visa_df['education_of_employee'].map(d)
# Out:
# 0        2
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 25475    0
# 25476    2
# 25477    3
# 25478    3
# 25479    0
# Name: education_of_employee, Length: 25480, dtype: int64

# %%
d
# Out:
# {"Bachelor's": 0, 'Doctorate': 1, 'High School': 2, "Master's": 3}

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
eduction         label encoder      original encoder
highschool         1                    0
bachelors         0                    1
masters           2                     2
phd               3                    3

1 0  2  3 ====> ml model sees this : 3>2>1>0
which indicates : phd>master>highschool>bachelors

# %%
- sklearn : package
  -preprocessig : module
     -labelencoder : class
       -fit_transform : method

import sklearn
sklearn.preprocessing

fromsklearn import preprocessing
dir(preprocessing) : Labelencoder
preprocessing.LabelEncoder

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()

#Read the class
#save the class
#apply the fit transform

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()

from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
oe.fit_transform()

# %%
fit transform
 - fit : created a dictionary (find something)
 -transform: using above finding we are modify the data

from sklearn.module import class
va=class()
va.fit or va.fit_transform

# %%
# labelencoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:                            # don't consider caseid
    
    visa_df[i]=le.fit_transform(visa_df[i])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df=pd.read_csv(r"D:\data files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in cat[1:]:
    visa_df[i]=oe.fit_transform(visa_df[[i]])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01        1.0                    2.0                 0.0
# 1         EZYV02        1.0                    3.0                 1.0
# 2         EZYV03        1.0                    0.0                 0.0
# 3         EZYV04        1.0                    0.0                 0.0
# 4         EZYV05        0.0                    3.0                 1.0
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476        1.0                    0.0                 1.0
# 25476  EZYV25477        1.0                    2.0                 1.0
# 25477  EZYV25478        1.0                    3.0                 1.0
# 25478  EZYV25479        1.0                    3.0                 1.0
# 25479  EZYV25480        1.0                    0.0                 1.0
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df=pd.read_csv(r"D:\data files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#pd.get_dummies

# %%
- get dummies is a way to represent the categorical columns to numerical
- first it will check what are labels in a column
- for example case status has two labels
- Denied and certified
- so it will creatr two new columns based on labels
- col1: case_status_denied
- col2: case_status_certified


case_status   |case_status_denied  | case_status_certified       

Denied           1                     0                   cos 0=1,cos90=0
certified        0                     1
certified        0                     1

- it is also called as one hot encoder
- it makes new columns are independent each other
- some of ml algorithmns expect that columns should be independent each other.

# %%
pd.get_dummies(visa_df['case_status'])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(visa_df['case_status'],dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]
